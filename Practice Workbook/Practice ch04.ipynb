# %% [markdown]
# ## Chapter 4
# ### Section 4.1: The NumPy ndarray

# %% [markdown]
# **Question 1:** Create a 2D NumPy array with 3 rows and 4 columns containing random numbers. Use the `.shape` and `.dtype` attributes to print the dimensions and the data type of the array. Why is it important that all elements in a NumPy array have the same data type?

# %%
# Type your solution here:

# %% [markdown]
# **Question 2:** If you create an array using `data = [6, 7.5, 8, 0, 1]`, what will be the resulting `dtype` of the NumPy array when you run `arr = np.array(data)`? Why does NumPy choose this specific type instead of keeping the integers as integers?

# %%
# Type your solution here:

# %% [markdown]
# ### Section 4.2: Data Types for ndarrays

# %% [markdown]
# **Question 1:**
# Given an array of strings `numeric_strings = np.array(['1.25', '-9.6', '42'], dtype=np.string_)`, write the code to convert (cast) this array to floating-point numbers. What happens to the original array if you don't assign the result to a new variable?

# %%
# Type your solution here:

# %% [markdown]
# **Question 2:** Use the `np.empty((2, 3))` function to create an array. Does this function create an array filled with zeros? Explain what "uninitialized" memory means in this context and why a student should be cautious when using this function.

# %%
# Type your solution here:

# %% [markdown]
# ### Section 4.3: Arithmetic with NumPy Arrays

# %% [markdown]
# **Question 1:**
# Create a 1D array of numbers from 0 to 9. Write a vectorized expression to calculate the square of each element and then subtract 5 from each result. Explain why you don't need a `for` loop to perform this task.

# %%
# Type your solution here:

# %% [markdown]
# **Question 2:** Create two $2 \times 2$ arrays, `A` and `B`, filled with any integers.
# 1. Perform the operation `A * B`.
# 2. Does this perform matrix multiplication or element-wise multiplication?
# 3. How would the result differ if you used a standard Python list instead of a NumPy array?

# %%
# Type your solution here:

# %% [markdown]
# ### Section 4.4: Basic Indexing and Slicing

# %% [markdown]
# **Question 1:**
# Create a $3 \times 3$ matrix with values ranging from 1 to 9.
# 1. Select the second row.
# 2. Select the element in the third row and first column.
# 3. If you create a slice of this array and change a value in that slice, does the original array change? Why or why not?

# %%
# Type your solution here:

# %% [markdown]
# **Question 2:** Given a 2D array, how do you select a "column" rather than a row? Write the slicing syntax to select the entire second column from a $4 \times 4$ matrix.

# %%
# Type your solution here:

# %% [markdown]
# ### Section 4.5: Boolean Indexing

# %% [markdown]
# **Question 1:**
# Suppose you have an array of names `names = np.array(['Bob', 'Joe', 'Will', 'Bob'])` and a corresponding $4 \times 4$ array of random data. Write the command to select all rows from the data array where the corresponding name in the `names` array is *not* 'Bob'.

# %%
# Type your solution here:

# %% [markdown]
# **Question 2:** You have an array of data: `data = np.array([1, 2, 3, 4, 5])`. Write a single line of code using a boolean mask to replace all values greater than 3 with the value 0. What is the state of the `data` array after this operation?

# %%
# Type your solution here:

# %% [markdown]
# ### Section 4.6: Fancy Indexing

# %% [markdown]
# **Question 1:**
# Create an $8 \times 4$ array using `np.arange(32).reshape((8, 4))`. Use "fancy indexing" (passing a list of integers) to select the 5th, 1st, and 3rd rows in that specific order.

# %%
# Type your solution here:

# %% [markdown]
# **Question 2:** Explain the difference in the *shape* of the result when you index a 2D array using:
# 1. `arr[[1, 3], [0, 2]]` (Passing two lists)
# 2. `arr[[1, 3]]` (Passing one list)
# *Note: This often confuses students—encourage them to test it in a cell!*

# %%
# Type your solution here:

# %% [markdown]
# ### Section 4.7: Transposing Arrays and Swapping Axes

# %% [markdown]
# **Question 1:**
# Given a $2 \times 3$ matrix, use the `.T` attribute to transpose it. Describe what happens to the shape of the matrix. In what common data science scenario (like a specific mathematical operation) is transposing a matrix usually required?

# %%
# Type your solution here:

# %% [markdown]
# **Question 2:** Beyond the simple `.T` attribute, NumPy has a `.swapaxes()` method. If you have a 3D array (a cube of data), what two arguments does `swapaxes` require, and how does it change the underlying data layout?

# %%
# Type your solution here:
